# %% [markdown]
# ## 189. Rotate Array. Medium
#
# Given an integer array nums, rotate the array to the right by k steps, where k is non-negative.
#
#
#
# Example 1:
#
# Input: nums = [1,2,3,4,5,6,7], k = 3
# Output: [5,6,7,1,2,3,4]
# Explanation:
# rotate 1 steps to the right: [7,1,2,3,4,5,6]
# rotate 2 steps to the right: [6,7,1,2,3,4,5]
# rotate 3 steps to the right: [5,6,7,1,2,3,4]
#
# Example 2:
#
# Input: nums = [-1,-100,3,99], k = 2
# Output: [3,99,-1,-100]
# Explanation:
# rotate 1 steps to the right: [99,-1,-100,3]
# rotate 2 steps to the right: [3,99,-1,-100]
#
#
# Constraints:
#
# 1 <= nums.length <= 105
#
# -231 <= nums[i] <= 231 - 1
#
# 0 <= k <= 105

# %%
from typing import List
class Solution:
    def rotate(self, nums: List[int], k: int) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        k = k % len(nums)
        nums[:] = nums[-k:] + nums[:-k]
        # firstly I use nums[:] = nums[len(nums) - k:] + nums[:len(nums) - k] but when k > len(nums) it crashes
        print(nums)

# %%
nums = [1,2,3,4,5,6,7]
k = 3

# %%
# %%time
sol = Solution()
sol.rotate(nums, k)
# Out:
# [5, 6, 7, 1, 2, 3, 4]
# CPU times: user 285 µs, sys: 129 µs, total: 414 µs
# Wall time: 353 µs

# %%
nums = [-1,-100,3,99]
k = 2

# %%
# %%time
sol = Solution()
sol.rotate(nums, k) # [3, 99, -1, -100]
# Out:
# [3, 99, -1, -100]
# CPU times: user 279 µs, sys: 128 µs, total: 407 µs
# Wall time: 349 µs

# %%
# %%time
nums = [1, 2]
k = 5

sol = Solution()
sol.rotate(nums, k) #[2, 1]
# Out:
# [2, 1]
# CPU times: user 275 µs, sys: 128 µs, total: 403 µs
# Wall time: 384 µs

# %%
# %%time
nums = [1, 2]
k = 3

sol = Solution()
sol.rotate(nums, k) #[1, 2]
# Out:
# [2, 1]
# CPU times: user 293 µs, sys: 121 µs, total: 414 µs
# Wall time: 358 µs

# %% [markdown]
# ![Screenshot%202023-04-07%20at%2008.57.00.png](attachment:Screenshot%202023-04-07%20at%2008.57.00.png)
