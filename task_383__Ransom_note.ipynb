# %% [markdown]
# ## 383. Ransom Note. Easy
#
# Companies
# Given two strings ransomNote and magazine, return true if ransomNote can be constructed by using the letters from magazine and false otherwise.
#
# Each letter in magazine can only be used once in ransomNote.
#
#
#
# Example 1:
#
# Input: ransomNote = "a", magazine = "b"
# Output: false
#
# Example 2:
#
# Input: ransomNote = "aa", magazine = "ab"
# Output: false
#
# Example 3:
#
# Input: ransomNote = "aa", magazine = "aab"
# Output: true

# %%
from typing import Counter
class Solution:
    def canConstruct(self, ransomNote: str, magazine: str) -> bool:
        d_1 = Counter(ransomNote)
        d_2 = Counter(magazine)
        return d_1 - d_2 == {}

# %%
# %%time
ransomNote = "a"
magazine = "b" #Output: false
sol = Solution()
sol.canConstruct(ransomNote, magazine)
# Out:
# CPU times: user 66 µs, sys: 1e+03 ns, total: 67 µs
# Wall time: 71 µs
# False

# %%
# %%time
ransomNote = "aa"
magazine = "ab" #Output: false
sol = Solution()
sol.canConstruct(ransomNote, magazine)
# Out:
# CPU times: user 59 µs, sys: 1 µs, total: 60 µs
# Wall time: 63.9 µs
# False

# %%
# %%time
ransomNote = "aa"
magazine = "aab" #Output: true
sol = Solution()
sol.canConstruct(ransomNote, magazine)
# Out:
# CPU times: user 119 µs, sys: 15 µs, total: 134 µs
# Wall time: 220 µs
# True

# %% [markdown]
# ![Screenshot%202023-04-17%20at%2012.11.28.png](attachment:Screenshot%202023-04-17%20at%2012.11.28.png)
