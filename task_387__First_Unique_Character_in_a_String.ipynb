# %% [markdown]
# ## 387. First Unique Character in a String. Easy
#
# Given a string s, find the first non-repeating character in it and return its index. If it does not exist, return -1.
#
#
#
# Example 1:
#
# Input: s = "leetcode"
# Output: 0
#
# Example 2:
#
# Input: s = "loveleetcode"
# Output: 2
#
# Example 3:
#
# Input: s = "aabb"
# Output: -1
#
#
# Constraints:
#
# * 1 <= s.length <= 105
# * s consists of only lowercase English letters.

# %%
class Solution:
    def firstUniqChar(self, s: str) -> int:
        letters='abcdefghijklmnopqrstuvwxyz'
        index=[s.index(l) for l in letters if s.count(l) == 1] #greg's solution
        return min(index) if len(index) > 0 else -1

# %%
# %%time
s = "leetcode" #Output: 0
sol = Solution()
sol.firstUniqChar(s)
# Out:
# CPU times: user 42 µs, sys: 0 ns, total: 42 µs
# Wall time: 47.2 µs
# 0

# %%
# %%time
s = "loveleetcode" #Output: 2
sol = Solution()
sol.firstUniqChar(s)
# Out:
# CPU times: user 51 µs, sys: 1 µs, total: 52 µs
# Wall time: 56.7 µs
# 2

# %%
# %%time
s = "aabb" #Output: -1
sol = Solution()
sol.firstUniqChar(s)
# Out:
# CPU times: user 46 µs, sys: 0 ns, total: 46 µs
# Wall time: 50.8 µs
# -1

# %%
# %%time
s = "dddccdbba"# Output: 8
sol = Solution()
sol.firstUniqChar(s)
# Out:
# CPU times: user 43 µs, sys: 0 ns, total: 43 µs
# Wall time: 47.7 µs
# 8

# %% [markdown]
# ![Screenshot%202023-04-17%20at%2011.47.47.png](attachment:Screenshot%202023-04-17%20at%2011.47.47.png)
