# %% [markdown]
# 977. Squares of a Sorted Array. Easy
#
# Given an integer array nums sorted in non-decreasing order, return an array of the squares of each number sorted in non-decreasing order.
#
#
#
# Example 1:
#
# Input: nums = [-4,-1,0,3,10]
# Output: [0,1,9,16,100]
# Explanation: After squaring, the array becomes [16,1,0,9,100].
# After sorting, it becomes [0,1,9,16,100].
#
# Example 2:
#
# Input: nums = [-7,-3,2,3,11]
# Output: [4,9,9,49,121]

# %%
from typing import List
class Solution:
    def sortedSquares(self, nums: List[int]) -> List[int]:
        start_point = 0
        end_point = len(nums) - 1
        res_arr = [0]*(end_point+1)
        while start_point <= end_point:
            left, right = abs(nums[start_point]), abs(nums[end_point])
            if left < right:
                res_arr[end_point - start_point] = right * right
                end_point -= 1
            else:
                res_arr[end_point - start_point] = left * left
                start_point += 1
        return res_arr

# %%
# %%time
sol = Solution()
nums = [-4, -1, 0, 3, 10]
sol.sortedSquares(nums)
# Out:
# CPU times: user 38 µs, sys: 1 µs, total: 39 µs
# Wall time: 43.2 µs
# [0, 1, 9, 16, 100]

# %%
# %%time
sol = Solution()
nums = [-7,-3,2,3,11]
sol.sortedSquares(nums)
# Out:
# CPU times: user 40 µs, sys: 1e+03 ns, total: 41 µs
# Wall time: 44.1 µs
# [4, 9, 9, 49, 121]

# %% [markdown]
# ![Screenshot%202023-04-07%20at%2008.08.07.png](attachment:Screenshot%202023-04-07%20at%2008.08.07.png)
