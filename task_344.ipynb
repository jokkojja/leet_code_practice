# %% [markdown]
# ## 344. Reverse String. Easy
#
# Write a function that reverses a string. The input string is given as an array of characters s.
#
# You must do this by modifying the input array in-place with O(1) extra memory.
#
#
#
# Example 1:
#
# Input: s = ["h","e","l","l","o"]
# Output: ["o","l","l","e","h"]
#
# Example 2:
#
# Input: s = ["H","a","n","n","a","h"]
# Output: ["h","a","n","n","a","H"]

# %%
from typing import List
class Solution:
    def reverseString(self, s: List[str]) -> None:
        """
        Do not return anything, modify s in-place instead.
        """
        s[:] = s[::-1] # slice method
        return s

# %%
# %%time
s = ["h","e","l","l","o"]
sol = Solution()
sol.reverseString(s)
# Out:
# CPU times: user 35 µs, sys: 0 ns, total: 35 µs
# Wall time: 39.1 µs
# ['o', 'l', 'l', 'e', 'h']

# %%
# %%time
s = ["H","a","n","n","a","h"] 
sol = Solution()
sol.reverseString(s)
# Out:
# CPU times: user 38 µs, sys: 1 µs, total: 39 µs
# Wall time: 44.1 µs
# ['h', 'a', 'n', 'n', 'a', 'H']

# %% [markdown]
# ![Screenshot%202023-04-09%20at%2012.29.44.png](attachment:Screenshot%202023-04-09%20at%2012.29.44.png)

# %%
from typing import List
class Solution:
    def reverseString(self, s: List[str]) -> None:
        """
        Do not return anything, modify s in-place instead.
        """
        last = len(s) - 1
        for i in range(len(s) // 2):
            s[i], s[last] = s[last], s[i] # two pointers method
            last -= 1
        return s

# %%
### %%time
s = ["h","e","l","l","o"]
sol = Solution()
sol.reverseString(s)
# Out:
# ['o', 'l', 'l', 'e', 'h']

# %%
# %%time
s = ["H","a","n","n","a","h"] 
sol = Solution()
sol.reverseString(s)
# Out:
# CPU times: user 36 µs, sys: 0 ns, total: 36 µs
# Wall time: 39.8 µs
# ['h', 'a', 'n', 'n', 'a', 'H']

# %% [markdown]
# ![Screenshot%202023-04-09%20at%2012.31.13.png](attachment:Screenshot%202023-04-09%20at%2012.31.13.png)
