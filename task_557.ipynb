# %% [markdown]
# 557. Reverse Words in a String III
#
# Given a string s, reverse the order of characters in each word within a sentence while still preserving whitespace and initial word order.
#
#
#
# Example 1:
#
# Input: s = "Let's take LeetCode contest"
# Output: "s'teL ekat edoCteeL tsetnoc"
#
# Example 2:
#
# Input: s = "God Ding"
# Output: "doG gniD"
#
#
# Constraints:
#
# * 1 <= s.length <= 5 * 104
#
# * s contains printable ASCII characters.
#
# * s does not contain any leading or trailing spaces.
#
# * There is at least one word in s.
#
# * All the words in s are separated by a single space.

# %%
from typing import List
class Solution:
    def reverseWords(self, s: str) -> str:
        splitted_str = s.split()
        ret_str = ''
        for word in splitted_str:
            ret_str += word[::-1] + ' '
        return ret_str.strip()

# %%
# %%time
s = "Let's take LeetCode contest" # Output: "s'teL ekat edoCteeL tsetnoc"
sol = Solution()
sol.reverseWords(s)
# Out:
# CPU times: user 37 µs, sys: 1 µs, total: 38 µs
# Wall time: 42.2 µs
# "s'teL ekat edoCteeL tsetnoc"

# %% [markdown]
# ![Screenshot%202023-04-09%20at%2012.38.58.png](attachment:Screenshot%202023-04-09%20at%2012.38.58.png)

# %%
class Solution:
    def reverseWords(self, s: str) -> str:
        s = s.split()
        for i, word in enumerate(s): # better memory solution
            s[i] = word[::-1]
        return ' '.join(s)

# %%
# %%time
s = "Let's take LeetCode contest" # Output: "s'teL ekat edoCteeL tsetnoc"
sol = Solution()
sol.reverseWords(s)
# Out:
# CPU times: user 34 µs, sys: 0 ns, total: 34 µs
# Wall time: 38.9 µs
# "s'teL ekat edoCteeL tsetnoc"

# %% [markdown]
# ![Screenshot%202023-04-09%20at%2012.43.04.png](attachment:Screenshot%202023-04-09%20at%2012.43.04.png)
